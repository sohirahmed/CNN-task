# %%
import keras
from keras.datasets import cifar10
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten, BatchNormalization
from keras.layers import Conv2D, MaxPooling2D
from keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt

# %%
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 13s 0us/step

# %%
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
num_classes = 10

y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# %%
x_train[444].shape
# Out:
# (32, 32, 3)

# %%
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
datagen = ImageDataGenerator(
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    zoom_range=0.2,
    shear_range=0.2,
    fill_mode='nearest'
)

# %%
model = Sequential()

# %%
model.add(Conv2D(64, (3, 3), padding='same', strides=(1, 1), input_shape=x_train.shape[1:]))
model.add(Activation('relu'))
model.add(BatchNormalization())

model.add(Conv2D(128, (3, 3), padding='same', strides=(1, 1)))
model.add(Activation('relu'))
model.add(BatchNormalization())

model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(256, (3, 3), padding='same', strides=(1, 1)))
model.add(Activation('relu'))
model.add(BatchNormalization())

model.add(Conv2D(256, (3, 3), padding='same', strides=(1, 1)))
model.add(Activation('relu'))
model.add(BatchNormalization())

model.add(MaxPooling2D(pool_size=(1,1 )))
model.add(Flatten())
model.add(Dense(4096  ))
model.add(Activation('relu'))
model.add(Dense(num_classes))
model.add(Activation('softmax'))

model.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 32, 32, 64)     │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 32, 32, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 32, 32, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 32, 32, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_1 (Activation)       │ (None, 32, 32, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 32, 32, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 16, 16, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 16, 16, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_2 (Activation)       │ (None, 16, 16, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 16, 16, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 16, 16, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_3 (Activation)       │ (None, 16, 16, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 16, 16, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 16, 16, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 65536)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 4096)           │   268,439,552 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_4 (Activation)       │ (None, 4096)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │        40,970 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_5 (Activation)       │ (None, 10)             │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 269,444,234 (1.00 GB)
#  Trainable params: 269,442,826 (1.00 GB)
#  Non-trainable params: 1,408 (5.50 KB)

# %%
opt = Adam(learning_rate=0.0005)
model.compile(loss='categorical_crossentropy',
              optimizer=opt,
              metrics=['accuracy'])

# %%
batch_size = 128
model.fit(datagen.flow(x_train, y_train, batch_size=batch_size),
          epochs=5,
          validation_data=(x_test, y_test))
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/5
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 90s 190ms/step - accuracy: 0.4261 - loss: 3.7080 - val_accuracy: 0.2216 - val_loss: 4.8118
# Epoch 2/5
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 59s 150ms/step - accuracy: 0.6255 - loss: 1.0591 - val_accuracy: 0.6907 - val_loss: 0.8945
# Epoch 3/5
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 61s 155ms/step - accuracy: 0.6850 - loss: 0.8925 - val_accuracy: 0.7020 - val_loss: 0.8833
# Epoch 4/5
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 61s 155ms/step - accuracy: 0.7250 - loss: 0.7891 - val_accuracy: 0.7010 - val_loss: 0.8960
# Epoch 5/5
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 61s 155ms/step - accuracy: 0.7532 - loss: 0.7065 - val_accuracy: 0.7542 - val_loss: 0.7274

# %%
batch_size = 128
model.fit(
    datagen.flow(x_train, y_train, batch_size=batch_size),
    epochs=15,
    validation_data=(x_test, y_test)
)
# Out:
# Epoch 1/15
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 59s 151ms/step - accuracy: 0.7742 - loss: 0.6532 - val_accuracy: 0.7655 - val_loss: 0.7127
# Epoch 2/15
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 61s 155ms/step - accuracy: 0.7958 - loss: 0.5903 - val_accuracy: 0.7601 - val_loss: 0.7799
# Epoch 3/15
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 61s 155ms/step - accuracy: 0.8104 - loss: 0.5511 - val_accuracy: 0.7887 - val_loss: 0.6359
# Epoch 4/15
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 59s 150ms/step - accuracy: 0.8244 - loss: 0.5075 - val_accuracy: 0.7594 - val_loss: 0.7184
# Epoch 5/15
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 61s 155ms/step - accuracy: 0.8306 - loss: 0.4843 - val_accuracy: 0.7915 - val_loss: 0.6948
# Epoch 6/15
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 61s 155ms/step - accuracy: 0.8415 - loss: 0.4548 - val_accuracy: 0.7847 - val_loss: 0.7495
# Epoch 7/15
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 61s 155ms/step - accuracy: 0.8501 - loss: 0.4366 - val_accuracy: 0.7938 - val_loss: 0.6547
# Epoch 8/15
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 61s 155ms/step - accuracy: 0.8613 - loss: 0.4046 - val_accuracy: 0.8070 - val_loss: 0.6232
# Epoch 9/15
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 59s 150ms/step - accuracy: 0.8662 - loss: 0.3874 - val_accuracy: 0.8217 - val_loss: 0.6002
# Epoch 10/15
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 59s 150ms/step - accuracy: 0.8738 - loss: 0.3711 - val_accuracy: 0.8203 - val_loss: 0.6001
# Epoch 11/15
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 61s 155ms/step - accuracy: 0.8810 - loss: 0.3487 - val_accuracy: 0.8226 - val_loss: 0.7378
# Epoch 12/15
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 61s 155ms/step - accuracy: 0.8843 - loss: 0.3400 - val_accuracy: 0.8339 - val_loss: 0.5718
# Epoch 13/15
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 82s 156ms/step - accuracy: 0.8876 - loss: 0.3236 - val_accuracy: 0.7839 - val_loss: 0.8589
# Epoch 14/15
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 59s 150ms/step - accuracy: 0.8883 - loss: 0.3255 - val_accuracy: 0.8239 - val_loss: 0.6564
# Epoch 15/15
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 61s 155ms/step - accuracy: 0.8939 - loss: 0.3103 - val_accuracy: 0.8263 - val_loss: 0.6522
